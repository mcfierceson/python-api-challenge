# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/marks_cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
api_key = weather_api_key

temp = []
humidity = []
clouds = []
wind = []
country = []
lat = []
lon = []
dates = []
cities_updated = []
city_count = 0
cities_length = len(cities)

query_url = f"{url}appid={api_key}&units={units}&q="

print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    city_count = city_count + 1
    response = requests.get(query_url + city).json()
    #error handling
    try:
        temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        country.append(response['sys']['country'])
        dates.append(response['dt'])
        cities_updated.append(response['name'])
        print(f"Processing {city_count} of {cities_length} | {city}")
    except KeyError:
        print("City not found. Skipping...")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing 1 of 602 | upernavik
# Processing 2 of 602 | rikitea
# City not found. Skipping...
# Processing 4 of 602 | pangnirtung
# Processing 5 of 602 | ponta do sol
# Processing 6 of 602 | tromso
# Processing 7 of 602 | vaini
# Processing 8 of 602 | east london
# Processing 9 of 602 | lasa
# Processing 10 of 602 | jamestown
# Processing 11 of 602 | salamiyah
# Processing 12 of 602 | arraial do cabo
# Processing 13 of 602 | bira
# Processing 14 of 602 | chokurdakh
# Processing 15 of 602 | chuy
# Processing 16 of 602 | mataura
# Processing 17 of 602 | bengkulu
# Processing 18 of 602 | galle
# Processing 19 of 602 | port alfred
# Processing 20 of 602 | ambon
# Processing 21 of 602 | muros
# Processing 22 of 602 | clyde river
# Processing 23 of 602 | severo-kurilsk
# Processing 24 of 602 | bilma
# Processing 25 of 602 | henties bay
# Processing 26 of 602 | hobart
# Processing 27 of 602 | quatre cocos
# City not found. Skipping...
# Processing 29 of 602 | aklavik
# Processing 30 of 602 | barrow
# Processing 31 of 602 | busselton
# Processing 32 of 602 | cam ranh
# Processing 33 of 602 | nikolskoye
# Processing 34 of 602 | redcliffe
# City not found. Skipping...
# City not found. Skipping...
# Processing 37 of 602 | torbay
# Processing 38 of 602 | sabzevar
# Processing 39 of 602 | palmer
# Processing 40 of 602 | ushuaia
# Processing 41 of 602 | hilo
# Processing 42 of 602 | atuona
# City not found. Skipping...
# Processing 44 of 602 | ostrovnoy
# Processing 45 of 602 | gushikawa
# Processing 46 of 602 | kununurra
# Processing 47 of 602 | naze
# Processing 48 of 602 | canutama
# Processing 49 of 602 | khatanga
# Processing 50 of 602 | albany
# Processing 51 of 602 | salalah
# Processing 52 of 602 | zhuzhou
# Processing 53 of 602 | aksarka
# Processing 54 of 602 | bluff
# City not found. Skipping...
# Processing 56 of 602 | mar del plata
# Processing 57 of 602 | nizhniy odes
# Processing 58 of 602 | hermanus
# Processing 59 of 602 | faanui
# Processing 60 of 602 | constitucion
# Processing 61 of 602 | mahebourg
# Processing 62 of 602 | kapaa
# Processing 63 of 602 | krasnoselkup
# Processing 64 of 602 | comodoro rivadavia
# Processing 65 of 602 | punta arenas
# Processing 66 of 602 | souillac
# Processing 67 of 602 | guerrero negro
# City not found. Skipping...
# Processing 69 of 602 | port elizabeth
# Processing 70 of 602 | tasiilaq
# Processing 71 of 602 | new norfolk
# Processing 72 of 602 | castro
# Processing 73 of 602 | kholm
# Processing 74 of 602 | mantua
# Processing 75 of 602 | smidovich
# Processing 76 of 602 | raudeberg
# Processing 77 of 602 | avarua
# Processing 78 of 602 | solnechnyy
# Processing 79 of 602 | nalut
# Processing 80 of 602 | skelleftea
# Processing 81 of 602 | palana
# Processing 82 of 602 | sakakah
# Processing 83 of 602 | arman
# Processing 84 of 602 | mount gambier
# City not found. Skipping...
# Processing 86 of 602 | coihaique
# Processing 87 of 602 | alamogordo
# Processing 88 of 602 | gayny
# Processing 89 of 602 | yumen
# Processing 90 of 602 | vao
# Processing 91 of 602 | yueyang
# Processing 92 of 602 | qaanaaq
# Processing 93 of 602 | kavieng
# Processing 94 of 602 | walvis bay
# Processing 95 of 602 | cockburn town
# Processing 96 of 602 | puerto ayora
# Processing 97 of 602 | kaitangata
# Processing 98 of 602 | amapa
# Processing 99 of 602 | tawang
# Processing 100 of 602 | pangody
# Processing 101 of 602 | andijon
# Processing 102 of 602 | airai
# Processing 103 of 602 | fortuna
# Processing 104 of 602 | nome
# Processing 105 of 602 | ribeira grande
# Processing 106 of 602 | sitka
# City not found. Skipping...
# Processing 108 of 602 | atambua
# Processing 109 of 602 | prince rupert
# Processing 110 of 602 | nagato
# Processing 111 of 602 | dikson
# Processing 112 of 602 | necochea
# Processing 113 of 602 | marbella
# Processing 114 of 602 | belyy yar
# Processing 115 of 602 | kodiak
# Processing 116 of 602 | staryy nadym
# Processing 117 of 602 | maceio
# Processing 118 of 602 | butaritari
# Processing 119 of 602 | ornskoldsvik
# City not found. Skipping...
# Processing 121 of 602 | norman wells
# Processing 122 of 602 | maldonado
# Processing 123 of 602 | antalya
# Processing 124 of 602 | bagnolo mella
# Processing 125 of 602 | adrar
# Processing 126 of 602 | phalodi
# Processing 127 of 602 | saskylakh
# Processing 128 of 602 | vylkove
# Processing 129 of 602 | kumano
# Processing 130 of 602 | carnarvon
# Processing 131 of 602 | nuuk
# City not found. Skipping...
# Processing 133 of 602 | mkushi
# Processing 134 of 602 | odweyne
# Processing 135 of 602 | serenje
# Processing 136 of 602 | tual
# Processing 137 of 602 | victoria
# Processing 138 of 602 | bambous virieux
# City not found. Skipping...
# Processing 140 of 602 | porto velho
# Processing 141 of 602 | sirnak
# Processing 142 of 602 | san patricio
# Processing 143 of 602 | kousseri
# Processing 144 of 602 | alice springs
# Processing 145 of 602 | furano
# Processing 146 of 602 | sao filipe
# Processing 147 of 602 | mitsamiouli
# City not found. Skipping...
# Processing 149 of 602 | marawi
# Processing 150 of 602 | bonavista
# Processing 151 of 602 | lisakovsk
# Processing 152 of 602 | fare
# Processing 153 of 602 | tiksi
# City not found. Skipping...
# Processing 155 of 602 | kamen-na-obi
# Processing 156 of 602 | hualmay
# Processing 157 of 602 | cape town
# City not found. Skipping...
# Processing 159 of 602 | maragogi
# Processing 160 of 602 | boffa
# Processing 161 of 602 | abbeville
# Processing 162 of 602 | hambantota
# Processing 163 of 602 | cherskiy
# Processing 164 of 602 | general pico
# Processing 165 of 602 | yellowknife
# City not found. Skipping...
# City not found. Skipping...
# Processing 168 of 602 | mongo
# Processing 169 of 602 | saurimo
# Processing 170 of 602 | borogontsy
# Processing 171 of 602 | pisco
# Processing 172 of 602 | port moresby
# Processing 173 of 602 | anadyr
# Processing 174 of 602 | richmond
# Processing 175 of 602 | rocha
# Processing 176 of 602 | okhotsk
# Processing 177 of 602 | nanortalik
# Processing 178 of 602 | victorville
# Processing 179 of 602 | kolvereid
# Processing 180 of 602 | cayenne
# City not found. Skipping...
# Processing 182 of 602 | dromolaxia
# City not found. Skipping...
# Processing 184 of 602 | roebourne
# Processing 185 of 602 | fairbanks
# Processing 186 of 602 | gribanovskiy
# City not found. Skipping...
# Processing 188 of 602 | shelburne
# Processing 189 of 602 | denpasar
# Processing 190 of 602 | hasaki
# Processing 191 of 602 | bollnas
# Processing 192 of 602 | lorengau
# Processing 193 of 602 | panama city
# Processing 194 of 602 | georgetown
# Processing 195 of 602 | awbari
# Processing 196 of 602 | yar-sale
# Processing 197 of 602 | havoysund
# Processing 198 of 602 | isangel
# Processing 199 of 602 | tashtagol
# Processing 200 of 602 | sambava
# Processing 201 of 602 | mandera
# Processing 202 of 602 | ancud
# Processing 203 of 602 | manta
# Processing 204 of 602 | tura
# Processing 205 of 602 | tuatapere
# Processing 206 of 602 | otradnoye
# Processing 207 of 602 | george town
# Processing 208 of 602 | rio grande
# Processing 209 of 602 | bariadi
# Processing 210 of 602 | marzuq
# Processing 211 of 602 | kavaratti
# Processing 212 of 602 | touros
# Processing 213 of 602 | noumea
# Processing 214 of 602 | lavrentiya
# Processing 215 of 602 | derzhavinsk
# Processing 216 of 602 | bredasdorp
# Processing 217 of 602 | montepuez
# Processing 218 of 602 | tuktoyaktuk
# Processing 219 of 602 | river falls
# City not found. Skipping...
# Processing 221 of 602 | thompson
# Processing 222 of 602 | mount isa
# Processing 223 of 602 | hithadhoo
# Processing 224 of 602 | budhlada
# Processing 225 of 602 | mineiros
# Processing 226 of 602 | price
# Processing 227 of 602 | puerto baquerizo moreno
# Processing 228 of 602 | aykhal
# Processing 229 of 602 | shimoda
# Processing 230 of 602 | seoul
# Processing 231 of 602 | kota belud
# Processing 232 of 602 | kahului
# Processing 233 of 602 | luderitz
# City not found. Skipping...
# City not found. Skipping...
# Processing 236 of 602 | pierre
# Processing 237 of 602 | fonte boa
# Processing 238 of 602 | iisalmi
# Processing 239 of 602 | havelock
# Processing 240 of 602 | panaba
# Processing 241 of 602 | trzebiatow
# Processing 242 of 602 | port hardy
# Processing 243 of 602 | lujiang
# Processing 244 of 602 | paamiut
# Processing 245 of 602 | salmas
# Processing 246 of 602 | longyearbyen
# Processing 247 of 602 | victoria falls
# Processing 248 of 602 | gravdal
# Processing 249 of 602 | nantucket
# Processing 250 of 602 | asau
# Processing 251 of 602 | ust-charyshskaya pristan
# Processing 252 of 602 | boa vista
# City not found. Skipping...
# Processing 254 of 602 | birnin kebbi
# Processing 255 of 602 | saint-philippe
# Processing 256 of 602 | llangefni
# Processing 257 of 602 | puerto carreno
# Processing 258 of 602 | hamilton
# Processing 259 of 602 | mozarlandia
# Processing 260 of 602 | ville-marie
# Processing 261 of 602 | soma
# Processing 262 of 602 | ilulissat
# Processing 263 of 602 | torata
# Processing 264 of 602 | quzhou
# Processing 265 of 602 | lesozavodsk
# Processing 266 of 602 | iskateley
# Processing 267 of 602 | swan hill
# Processing 268 of 602 | concepcion
# Processing 269 of 602 | siavonga
# City not found. Skipping...
# Processing 271 of 602 | yabelo
# Processing 272 of 602 | cauquenes
# Processing 273 of 602 | smithers
# Processing 274 of 602 | kamiiso
# Processing 275 of 602 | vanimo
# Processing 276 of 602 | luanda
# Processing 277 of 602 | sola
# Processing 278 of 602 | harper
# Processing 279 of 602 | jardim
# Processing 280 of 602 | klaksvik
# Processing 281 of 602 | campo grande
# Processing 282 of 602 | kasulu
# Processing 283 of 602 | geraldton
# Processing 284 of 602 | esperance
# Processing 285 of 602 | samarai
# City not found. Skipping...
# Processing 287 of 602 | cameta
# Processing 288 of 602 | erdaojiang
# City not found. Skipping...
# Processing 290 of 602 | nouakchott
# Processing 291 of 602 | salina cruz
# Processing 292 of 602 | svetlyy
# Processing 293 of 602 | boyolangu
# Processing 294 of 602 | thinadhoo
# Processing 295 of 602 | broken hill
# Processing 296 of 602 | goba
# Processing 297 of 602 | rundu
# Processing 298 of 602 | saint george
# Processing 299 of 602 | lagoa
# Processing 300 of 602 | nohar
# City not found. Skipping...
# Processing 302 of 602 | berdigestyakh
# City not found. Skipping...
# Processing 304 of 602 | shenjiamen
# Processing 305 of 602 | karpogory
# Processing 306 of 602 | saint-pierre
# Processing 307 of 602 | wajima
# Processing 308 of 602 | markala
# Processing 309 of 602 | chingirlau
# Processing 310 of 602 | brodnica
# Processing 311 of 602 | chenzhou
# Processing 312 of 602 | nabinagar
# Processing 313 of 602 | kasongo-lunda
# Processing 314 of 602 | dhidhdhoo
# Processing 315 of 602 | dingle
# Processing 316 of 602 | monte patria
# Processing 317 of 602 | hobyo
# Processing 318 of 602 | tabou
# Processing 319 of 602 | sorland
# Processing 320 of 602 | warrnambool
# Processing 321 of 602 | taoudenni
# Processing 322 of 602 | san quintin
# Processing 323 of 602 | morwell
# Processing 324 of 602 | pasco
# Processing 325 of 602 | kloulklubed
# Processing 326 of 602 | padang
# Processing 327 of 602 | port lincoln
# City not found. Skipping...
# Processing 329 of 602 | bunia
# Processing 330 of 602 | ahuimanu
# Processing 331 of 602 | toamasina
# City not found. Skipping...
# Processing 333 of 602 | sabha
# Processing 334 of 602 | el alto
# Processing 335 of 602 | deputatskiy
# Processing 336 of 602 | santa cruz
# Processing 337 of 602 | maputo
# Processing 338 of 602 | polikhronon
# Processing 339 of 602 | sao joao da barra
# Processing 340 of 602 | broome
# Processing 341 of 602 | bardiyah
# Processing 342 of 602 | kokopo
# Processing 343 of 602 | frystak
# Processing 344 of 602 | belaya gora
# Processing 345 of 602 | te anau
# Processing 346 of 602 | saryg-sep
# City not found. Skipping...
# Processing 348 of 602 | orissaare
# Processing 349 of 602 | serra branca
# Processing 350 of 602 | mango
# Processing 351 of 602 | vila
# Processing 352 of 602 | meadow lake
# Processing 353 of 602 | batemans bay
# Processing 354 of 602 | karratha
# Processing 355 of 602 | panzhihua
# City not found. Skipping...
# Processing 357 of 602 | berlevag
# Processing 358 of 602 | chengalpattu
# Processing 359 of 602 | alugan
# Processing 360 of 602 | santa adelia
# Processing 361 of 602 | matara
# Processing 362 of 602 | pendleton
# Processing 363 of 602 | vermilion
# Processing 364 of 602 | khuchni
# Processing 365 of 602 | guanica
# City not found. Skipping...
# Processing 367 of 602 | san juan
# Processing 368 of 602 | nara
# Processing 369 of 602 | tulua
# Processing 370 of 602 | leningradskiy
# Processing 371 of 602 | gurupa
# Processing 372 of 602 | svetlogorsk
# Processing 373 of 602 | katsuura
# City not found. Skipping...
# Processing 375 of 602 | mocuba
# Processing 376 of 602 | castelldefels
# Processing 377 of 602 | olafsvik
# Processing 378 of 602 | durham
# Processing 379 of 602 | aquiraz
# Processing 380 of 602 | pevek
# Processing 381 of 602 | nelson bay
# Processing 382 of 602 | tezu
# Processing 383 of 602 | high level
# Processing 384 of 602 | aksu
# Processing 385 of 602 | nizhnyaya poyma
# City not found. Skipping...
# Processing 387 of 602 | saldanha
# City not found. Skipping...
# Processing 389 of 602 | medvedka
# City not found. Skipping...
# City not found. Skipping...
# Processing 392 of 602 | inhambane
# Processing 393 of 602 | kupang
# Processing 394 of 602 | husavik
# Processing 395 of 602 | pacific grove
# Processing 396 of 602 | jalu
# Processing 397 of 602 | bonthe
# Processing 398 of 602 | tekkali
# Processing 399 of 602 | port macquarie
# Processing 400 of 602 | carutapera
# Processing 401 of 602 | hammerfest
# Processing 402 of 602 | kruisfontein
# Processing 403 of 602 | rio gallegos
# Processing 404 of 602 | cidreira
# Processing 405 of 602 | verkhnyaya toyma
# Processing 406 of 602 | kenora
# Processing 407 of 602 | nhulunbuy
# Processing 408 of 602 | cabo san lucas
# Processing 409 of 602 | bethel
# Processing 410 of 602 | minsk
# Processing 411 of 602 | bilibino
# Processing 412 of 602 | marienburg
# Processing 413 of 602 | eyl
# Processing 414 of 602 | avera
# Processing 415 of 602 | kirakira
# Processing 416 of 602 | kalmunai
# Processing 417 of 602 | flinders
# Processing 418 of 602 | meulaboh
# Processing 419 of 602 | biak
# Processing 420 of 602 | kulu
# Processing 421 of 602 | dumai
# Processing 422 of 602 | sangar
# Processing 423 of 602 | starkville
# Processing 424 of 602 | jashpurnagar
# Processing 425 of 602 | kapit
# Processing 426 of 602 | nataga
# Processing 427 of 602 | vila franca do campo
# Processing 428 of 602 | ignalina
# Processing 429 of 602 | chunoyar
# Processing 430 of 602 | teya
# Processing 431 of 602 | iqaluit
# Processing 432 of 602 | marshfield
# Processing 433 of 602 | binzhou
# Processing 434 of 602 | sonoma
# Processing 435 of 602 | turukhansk
# Processing 436 of 602 | narsaq
# Processing 437 of 602 | codrington
# Processing 438 of 602 | camacupa
# Processing 439 of 602 | tahe
# Processing 440 of 602 | beringovskiy
# Processing 441 of 602 | indian head
# Processing 442 of 602 | heilbron
# Processing 443 of 602 | dakar
# Processing 444 of 602 | bac lieu
# City not found. Skipping...
# Processing 446 of 602 | juruti
# City not found. Skipping...
# Processing 448 of 602 | sabang
# Processing 449 of 602 | cap malheureux
# Processing 450 of 602 | matagami
# Processing 451 of 602 | khani
# Processing 452 of 602 | lieksa
# Processing 453 of 602 | srivardhan
# Processing 454 of 602 | krutinka
# Processing 455 of 602 | grindavik
# Processing 456 of 602 | pedreiras
# Processing 457 of 602 | bako
# Processing 458 of 602 | lompoc
# Processing 459 of 602 | newcastle
# Processing 460 of 602 | yago
# Processing 461 of 602 | kaura namoda
# Processing 462 of 602 | kasama
# Processing 463 of 602 | artyom
# Processing 464 of 602 | ust-shonosha
# Processing 465 of 602 | christchurch
# Processing 466 of 602 | valparaiso
# Processing 467 of 602 | asosa
# Processing 468 of 602 | san luis
# Processing 469 of 602 | yangambi
# Processing 470 of 602 | tarbes
# Processing 471 of 602 | lebu
# Processing 472 of 602 | bonfim
# Processing 473 of 602 | kashi
# Processing 474 of 602 | saquena
# Processing 475 of 602 | yulara
# Processing 476 of 602 | bhavnagar
# Processing 477 of 602 | nevelsk
# Processing 478 of 602 | sanandaj
# Processing 479 of 602 | mataram
# Processing 480 of 602 | bubaque
# Processing 481 of 602 | ngara
# Processing 482 of 602 | nanakuli
# Processing 483 of 602 | itamaraca
# City not found. Skipping...
# Processing 485 of 602 | tazovskiy
# City not found. Skipping...
# Processing 487 of 602 | russell
# Processing 488 of 602 | xinzhi
# Processing 489 of 602 | vila do maio
# Processing 490 of 602 | karbinci
# Processing 491 of 602 | tala
# Processing 492 of 602 | miri
# Processing 493 of 602 | vardo
# Processing 494 of 602 | palora
# Processing 495 of 602 | cinisi
# Processing 496 of 602 | gadarwara
# Processing 497 of 602 | indore
# Processing 498 of 602 | huarmey
# Processing 499 of 602 | alta floresta
# Processing 500 of 602 | sandwick
# Processing 501 of 602 | margate
# Processing 502 of 602 | bukachacha
# Processing 503 of 602 | poum
# Processing 504 of 602 | kulachi
# Processing 505 of 602 | almunecar
# Processing 506 of 602 | abha
# Processing 507 of 602 | marsa matruh
# Processing 508 of 602 | rivera
# Processing 509 of 602 | olinda
# Processing 510 of 602 | khandyga
# Processing 511 of 602 | juneau
# Processing 512 of 602 | tanta
# Processing 513 of 602 | lerwick
# City not found. Skipping...
# Processing 515 of 602 | mastic beach
# Processing 516 of 602 | tiznit
# Processing 517 of 602 | limbang
# Processing 518 of 602 | pizhma
# Processing 519 of 602 | buala
# Processing 520 of 602 | usinsk
# Processing 521 of 602 | rayong
# Processing 522 of 602 | kaeo
# Processing 523 of 602 | provideniya
# City not found. Skipping...
# Processing 525 of 602 | norwich
# Processing 526 of 602 | zapatoca
# Processing 527 of 602 | sadat
# City not found. Skipping...
# City not found. Skipping...
# Processing 530 of 602 | kimberley
# Processing 531 of 602 | yerbogachen
# Processing 532 of 602 | boddam
# City not found. Skipping...
# Processing 534 of 602 | rutana
# Processing 535 of 602 | sibolga
# Processing 536 of 602 | kuvshinovo
# Processing 537 of 602 | bakel
# Processing 538 of 602 | ensenada
# Processing 539 of 602 | opunake
# Processing 540 of 602 | namibe
# Processing 541 of 602 | manado
# Processing 542 of 602 | baragua
# Processing 543 of 602 | zyryanka
# Processing 544 of 602 | chara
# Processing 545 of 602 | stade
# City not found. Skipping...
# Processing 547 of 602 | aras
# Processing 548 of 602 | voi
# Processing 549 of 602 | petropavlovsk-kamchatskiy
# Processing 550 of 602 | jelenia gora
# Processing 551 of 602 | mogadishu
# Processing 552 of 602 | irricana
# Processing 553 of 602 | santa isabel do rio negro
# Processing 554 of 602 | bafoulabe
# Processing 555 of 602 | tazmalt
# Processing 556 of 602 | raga
# Processing 557 of 602 | san mateo del mar
# Processing 558 of 602 | andenes
# Processing 559 of 602 | mehran
# Processing 560 of 602 | nueve de julio
# Processing 561 of 602 | otane
# Processing 562 of 602 | kholodnyy
# Processing 563 of 602 | mayo
# Processing 564 of 602 | port hedland
# Processing 565 of 602 | ahipara
# Processing 566 of 602 | tucuma
# Processing 567 of 602 | korla
# Processing 568 of 602 | gizo
# Processing 569 of 602 | north platte
# Processing 570 of 602 | tukrah
# Processing 571 of 602 | maryville
# Processing 572 of 602 | quthing
# Processing 573 of 602 | chimbote
# Processing 574 of 602 | puerto escondido
# Processing 575 of 602 | tomatlan
# Processing 576 of 602 | banning
# Processing 577 of 602 | eyrarbakki
# Processing 578 of 602 | inta
# Processing 579 of 602 | grand gaube
# Processing 580 of 602 | antofagasta
# Processing 581 of 602 | kropotkin
# Processing 582 of 602 | lianyuan
# City not found. Skipping...
# Processing 584 of 602 | bijar
# Processing 585 of 602 | kailua
# Processing 586 of 602 | ulaanbaatar
# Processing 587 of 602 | astoria
# Processing 588 of 602 | reyes
# Processing 589 of 602 | yakima
# Processing 590 of 602 | jinxiang
# City not found. Skipping...
# City not found. Skipping...
# Processing 593 of 602 | westport
# Processing 594 of 602 | rovaniemi
# Processing 595 of 602 | taltal
# Processing 596 of 602 | komagane
# Processing 597 of 602 | dalby
# Processing 598 of 602 | dashtavan
# Processing 599 of 602 | pasinler
# Processing 600 of 602 | ayagoz
# Processing 601 of 602 | sinnamary
# Processing 602 of 602 | kopervik

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": cities_updated,
    "Country": country,
    "Date": dates,
    "Max Temp": temp,
    "Humidity": humidity,
    "Cloudiness": clouds,
    "Wind Speed": wind,
    "Lat": lat,
    "Lng": lon
}
weather_df = pd.DataFrame(weather_dict)
weather_df.to_csv(output_data_file, index=False, header=True)
weather_df.head()
# Out:
#              City Country        Date  Max Temp  Humidity  Cloudiness  \
# 0       Upernavik      GL  1587491938     -0.25        90         100
# 1         Rikitea      PF  1587491938     25.39        72          22
# 2     Pangnirtung      CA  1587491938    -11.00        85          90
# 3    Ponta do Sol      PT  1587491938     17.22        59          40
# 4          Tromsø      NO  1587491939      4.00        64          67
# ..            ...     ...         ...       ...       ...         ...
# 545     Dashtavan      AM  1587492017     13.00        82          90
# 546      Pasinler      TR  1587492017      8.00        75          75
# 547        Ayagoz      KZ  1587492017     13.27        34           0
# 548     Sinnamary      GF  1587492018     26.87        83          89
# 549      Kopervik      NO  1587492018     15.56        71           0
#
#      Wind Speed    Lat     Lng
# 0          2.95  72.79  -56.15
# 1          3.48 -23.12 -134.97
# 2          2.60  66.15  -65.71
# 3          3.60  32.67  -17.10
# 4          3.60  69.65   18.96
# ..          ...    ...     ...
# 545        1.00  40.10   44.39
# 546        4.10  39.98   41.68
# 547        4.13  47.97   80.44
# 548        6.57   5.38  -52.95
# 549        5.10  59.28    5.31
#
# [550 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Functions
def scatterPlot (x_axis, y_axis, title, xlabel, ylabel):
    plt.scatter(x_axis, y_axis, marker="o", facecolors="steelblue", edgecolors="darkslategray")
    plt.grid()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

# %%
temp_f = ((weather_df['Max Temp']) * 9/5) + 32 
latitude = weather_df['Lat']
data_date = weather_df['Date'][0]
dateconvert = pd.to_datetime(data_date, unit='s')
date = dateconvert.date()
LatTempPlot = scatterPlot(latitude, temp_f, f"City Latitude vs Max Temperature {date}", "City Latitude", "Max Temperature (F)")
png = plt.savefig("../output_data/latVSMax.png")

# %% [markdown]
# Code is converting the date stamp for chart title and sending max temp in fahrenheit and latitude to the scatter plot function. Max temperature gets higher the closer to 0 latitude, equator.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humid = weather_df['Humidity']
LatHumidPlot = scatterPlot(latitude, humid, f"City Latitude vs Humidity {date}", "City Latitude", "Humidity (%)")
png = plt.savefig("../output_data/latVSHumid.png")

# %% [markdown]
# Code is sending humidity and latitude per city to the scatter plot function. Humidity varies regardless of latitude.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness = weather_df['Cloudiness']
LatCloudPlot = scatterPlot(latitude, cloudiness, f"City Latitude vs Cloudiness {date}", "City Latitude", "Cloudiness (%)")
png = plt.savefig("../output_data/latVSCloud.png")

# %% [markdown]
# Code is sending cloudiness and latitude per city to the scatter plot function. Cloudiness varies widely regardless of latitude.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
windspeed = weather_df['Wind Speed'] *  0.6213711922
LatWindPlot = scatterPlot(latitude, windspeed, f"City Latitude vs Wind Speed {date}", "City Latitude", "Wind Speed (mph)")
png = plt.savefig("../output_data/latVSWind.png")

# %% [markdown]
# Code is sending wind speed and latitude per city to the scatter plot function. Wind speed appears to increase above average beyond +-50 latitude.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def lin_regress(x, y):
    vc_slope, vc_int, vc_r, vc_p, vc_std_err = stats.linregress(x, y)
    vc_fit = vc_slope * x + vc_int
    line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
    return {'fit': vc_fit, 'r': vc_r, 'line_eq': line_eq}

# %%
# Create Northern and Southern Hemisphere DataFrames
north_df = weather_df[weather_df['Lat'] >= 0]
south_df = weather_df[weather_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = north_df['Lat']
temp_f = ((north_df['Max Temp']) * 9/5) + 32
result = lin_regress(latitude, temp_f)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
NLatTempPlot = scatterPlot(latitude, temp_f, "N. Hemisphere Latitude vs Max Temp Linear Regression", "Latitude", "Max Temp")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
png = plt.savefig("../output_data/NlatVSRegressTemp.png")
# Out:
# The r-squared is: 0.7174136257606091

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
latitude = south_df['Lat']
temp_f = ((south_df['Max Temp']) * 9/5) + 32
result = lin_regress(latitude, temp_f)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
SLatTempPlot = scatterPlot(latitude, temp_f, "S. Hemisphere Latitude vs Max Temp Linear Regression", "Latitude", "Max Temp")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(-45,90),fontsize=15,color="red")
png = plt.savefig("../output_data/SlatVSRegressTemp.png")
# Out:
# The r-squared is: 0.5234865089021224

# %% [markdown]
# Linear regression demonstrates relationship between max temperature increasing the closer latitude is to 0, from northern or southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = north_df['Lat']
humidity = north_df['Humidity']
result = lin_regress(latitude, humidity)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
NHLatTempPlot = scatterPlot(latitude, humidity, "N. Hemisphere Latitude vs Humidity Linear Regression", "Latitude", "Humidity")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(42,10),fontsize=15,color="red")
png = plt.savefig("../output_data/NlatVSRegressHumid.png")
# Out:
# The r-squared is: 0.08053502473584874

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
latitude = south_df['Lat']
humidity = south_df['Humidity']
result = lin_regress(latitude, humidity)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
SHLatTempPlot = scatterPlot(latitude, humidity, "S. Hemisphere Latitude vs Humidity Linear Regression", "Latitude", "Humidity")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(-55,20),fontsize=15,color="red")
png = plt.savefig("../output_data/SlatVSRegressTemp.png")
# Out:
# The r-squared is: 0.009873201384581651

# %% [markdown]
# Though there appeared to be no relation between humidity and lateral location across hemispheres, the regression line shows a slight increase in humidity from southernmost latitude to northernmost.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = north_df['Lat']
clouds = north_df['Cloudiness']
result = lin_regress(latitude, clouds)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
NCLatTempPlot = scatterPlot(latitude, clouds, "N. Hemisphere Latitude vs Cloudiness Linear Regression", "Latitude", "Cloudiness")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
png = plt.savefig("../output_data/NlatVSRegressCloud.png")
# Out:
# The r-squared is: 0.0047316787868733985

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
latitude = south_df['Lat']
clouds = south_df['Cloudiness']
result = lin_regress(latitude, clouds)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
SCLatTempPlot = scatterPlot(latitude, clouds, "S. Hemisphere Latitude vs Cloudiness Linear Regression", "Latitude", "Cloudiness")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(-54,18),fontsize=15,color="red")
png = plt.savefig("../output_data/SlatVSRegressCloud.png")
# Out:
# The r-squared is: 0.01018429469977307

# %% [markdown]
# Though there appeared to be no relation between cloudiness and lateral location across hemispheres, the regression line shows a slight increase in cloudiness from southernmost latitude to northernmost.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = north_df['Lat']
wind = north_df['Wind Speed']
result = lin_regress(latitude, wind)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
NWLatTempPlot = scatterPlot(latitude, wind, "N. Hemisphere Latitude vs Wind Speed Linear Regression", "Latitude", "Wind Speed")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(6,15),fontsize=15,color="red")
png = plt.savefig("../output_data/NlatVSRegressWind.png")
# Out:
# The r-squared is: 0.03268029703151839

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
latitude = south_df['Lat']
wind = south_df['Wind Speed']
result = lin_regress(latitude, wind)
w_fit = result['fit']
r_value = result['r']
line_eq = result['line_eq']
print(f"The r-squared is: {r_value**2}")
SWLatTempPlot = scatterPlot(latitude, wind, "S. Hemisphere Latitude vs Wind Speed Linear Regression", "Latitude", "Wind Speed")
plt.plot(latitude,w_fit,"--",color="red")
plt.annotate(line_eq,(-40,12),fontsize=15,color="red")
png = plt.savefig("../output_data/SlatVSRegressWind.png")
# Out:
# The r-squared is: 0.06500695807339464

# %% [markdown]
# Wind speed is highest at the extremes of latitude and decreases as you get towards the equator.
